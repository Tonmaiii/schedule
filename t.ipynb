# %%
data = {
    "teachers": 20,
    "classes": 6,
    "rooms": 30,
    "subjects": [
        # class 0 subjects
        {
            "classes": [0],
            "teachers": [0],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [0],
            "teachers": [1],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [0],
            "teachers": [2],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [0],
            "teachers": [3],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [0],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [0],
            "teachers": [5],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [0],
            "teachers": [6],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [0],
            "teachers": [7],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [0],
            "teachers": [8],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [0],
            "teachers": [9],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # class 1 subjects
        {
            "classes": [1],
            "teachers": [0],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [1],
            "teachers": [1],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [1],
            "teachers": [2],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [1],
            "teachers": [3],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [1],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [1],
            "teachers": [5],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [1],
            "teachers": [6],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [1],
            "teachers": [7],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [1],
            "teachers": [8],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [1],
            "teachers": [9],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # class 2 subjects
        {
            "classes": [2],
            "teachers": [0],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [2],
            "teachers": [1],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [2],
            "teachers": [2],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [2],
            "teachers": [3],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [2],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [2],
            "teachers": [5],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [2],
            "teachers": [6],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [2],
            "teachers": [7],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [2],
            "teachers": [8],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [2],
            "teachers": [9],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # class 3 subjects
        {
            "classes": [3],
            "teachers": [10],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [3],
            "teachers": [11],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [3],
            "teachers": [12],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [3],
            "teachers": [13],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [3],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [3],
            "teachers": [15],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [3],
            "teachers": [16],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [3],
            "teachers": [17],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [3],
            "teachers": [18],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [3],
            "teachers": [19],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # class 4 subjects
        {
            "classes": [4],
            "teachers": [10],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [4],
            "teachers": [11],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [4],
            "teachers": [12],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [4],
            "teachers": [13],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [4],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [4],
            "teachers": [15],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [4],
            "teachers": [16],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [4],
            "teachers": [17],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [4],
            "teachers": [18],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [4],
            "teachers": [19],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # class 5 subjects
        {
            "classes": [5],
            "teachers": [10],
            "periods_per_week": 2,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [5],
            "teachers": [11],
            "periods_per_week": 2,
            "available_rooms": [3, 4, 5]
        },
        {
            "classes": [5],
            "teachers": [12],
            "periods_per_week": 3,
            "available_rooms": [6, 7, 8]
        },
        {
            "classes": [5],
            "teachers": [13],
            "periods_per_week": 2,
            "available_rooms": [9, 10, 11]
        },
        {
            "classes": [5],
            "teachers": [4],
            "periods_per_week": 1,
            "available_rooms": [12, 13, 14]
        },
        {
            "classes": [5],
            "teachers": [15],
            "periods_per_week": 1,
            "available_rooms": [15, 16, 17]
        },
        {
            "classes": [5],
            "teachers": [16],
            "periods_per_week": 2,
            "available_rooms": [18, 19, 20]
        },
        {
            "classes": [5],
            "teachers": [17],
            "periods_per_week": 2,
            "available_rooms": [21, 22, 23]
        },
        {
            "classes": [5],
            "teachers": [18],
            "periods_per_week": 3,
            "available_rooms": [24, 25, 26]
        },
        {
            "classes": [5],
            "teachers": [19],
            "periods_per_week": 1,
            "available_rooms": [27, 28, 29]
        },
        # joint classes
        {
            "classes": [0, 1],
            "teachers": [0, 10],
            "periods_per_week": 1,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [2, 3],
            "teachers": [0, 10],
            "periods_per_week": 1,
            "available_rooms": [0, 1, 2]
        },
        {
            "classes": [4, 5],
            "teachers": [0, 10],
            "periods_per_week": 1,
            "available_rooms": [0, 1, 2]
        }
    ]
}

for subject in data['subjects']:
    subject['name'] = f's{subject["teachers"][0] % 10} c{subject["classes"][0]}'

print(data)
# Out:
# {'teachers': 20, 'classes': 6, 'rooms': 30, 'subjects': [{'classes': [0], 'teachers': [0], 'periods_per_week': 2, 'available_rooms': [0, 1, 2], 'name': 's0 c0'}, {'classes': [0], 'teachers': [1], 'periods_per_week': 2, 'available_rooms': [3, 4, 5], 'name': 's1 c0'}, {'classes': [0], 'teachers': [2], 'periods_per_week': 3, 'available_rooms': [6, 7, 8], 'name': 's2 c0'}, {'classes': [0], 'teachers': [3], 'periods_per_week': 2, 'available_rooms': [9, 10, 11], 'name': 's3 c0'}, {'classes': [0], 'teachers': [4], 'periods_per_week': 1, 'available_rooms': [12, 13, 14], 'name': 's4 c0'}, {'classes': [0], 'teachers': [5], 'periods_per_week': 1, 'available_rooms': [15, 16, 17], 'name': 's5 c0'}, {'classes': [0], 'teachers': [6], 'periods_per_week': 2, 'available_rooms': [18, 19, 20], 'name': 's6 c0'}, {'classes': [0], 'teachers': [7], 'periods_per_week': 2, 'available_rooms': [21, 22, 23], 'name': 's7 c0'}, {'classes': [0], 'teachers': [8], 'periods_per_week': 3, 'available_rooms': [24, 25, 26
# ...
